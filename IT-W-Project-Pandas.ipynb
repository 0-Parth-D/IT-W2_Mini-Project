# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
Netflix_data = pd.read_csv(r"C:\Users\Parth\Downloads\8. Netflix Dataset.csv")

# %%
Netflix_data.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
Netflix_data[Netflix_data.duplicated()]
# Out:
#      Show_Id Category              Title        Director  \
# 6300    s684    Movie           Backfire     Dave Patten
# 6622   s6621    Movie  The Lost Okoroshi  Abba T. Makama
#
#                                                    Cast        Country  \
# 6300  Black Deniro, Byron "Squally" Vinson, Dominic ...  United States
# 6622  Seun Ajayi, Judith Audu, Tope Tedela, Ifu Enna...        Nigeria
#
#            Release_Date Rating Duration  \
# 6300      April 5, 2019  TV-MA   97 min
# 6622  September 4, 2020  TV-MA   94 min
#
#                                        Type  \
# 6300  Dramas, Independent Movies, Thrillers
# 6622   Comedies, Dramas, Independent Movies
#
#                                             Description
# 6300  When two would-be robbers accidentally kill a ...
# 6622  A disillusioned security guard transforms into...

# %%
Netflix_data = Netflix_data.drop_duplicates()

# %%
Netflix_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7787 entries, 0 to 7788
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_Id       7787 non-null   object
#  1   Category      7787 non-null   object
#  2   Title         7787 non-null   object
#  3   Director      5399 non-null   object
#  4   Cast          7069 non-null   object
#  5   Country       7280 non-null   object
#  6   Release_Date  7777 non-null   object
#  7   Rating        7780 non-null   object
#  8   Duration      7787 non-null   object
#  9   Type          7787 non-null   object
#  10  Description   7787 non-null   object
# dtypes: object(11)
# memory usage: 730.0+ KB

# %%
Netflix_data.isnull().sum()
# Out:
# Show_Id            0
# Category           0
# Title              0
# Director        2388
# Cast             718
# Country          507
# Release_Date      10
# Rating             7
# Duration           0
# Type               0
# Description        0
# dtype: int64

# %%
sns.heatmap(Netflix_data.isnull())
# Out:
# <AxesSubplot:>

# %%
#1
show_name = input("Enter the show name:- ")
show = Netflix_data[Netflix_data.Title.str.contains(show_name)]
show
# Out:
# Enter the show name:- Money
#      Show_Id Category                                Title  \
# 958     s959  TV Show                     Black Money Love
# 987     s988    Movie                          Blood Money
# 1650   s1651    Movie  Dead in a Week (Or Your Money Back)
# 1773   s1774  TV Show                          Dirty Money
# 2225   s2226    Movie                    For Love or Money
# 3839   s3840    Movie                            Mad Money
# 4161   s4162    Movie                       Moh Maya Money
# 4174   s4175    Movie                                Money
# 4175   s4176  TV Show                    Money for Nothing
# 4176   s4177    Movie          Money Heist: The Phenomenon
# 4177   s4178    Movie                          Money Talks
# 4178   s4179    Movie                           Money Trap
# 4452   s4453    Movie                            New Money
# 4603   s4604  TV Show                            Old Money
# ...

# %%
#2
date_time = pd.to_datetime(Netflix_data.Release_Date)
date_time_year = date_time.dt.year
Netflix_data['Year'] = date_time_year
Netflix_data.Year.value_counts().sort_index().plot(kind = 'bar', color = 'red', width = 0.7)
# Out:
# <AxesSubplot:>

# %%
#6
Netflix_data.Director.value_counts().head()
# Out:
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Youssef Chahine           12
# Name: Director, dtype: int64

# %%
Netflix_data_new = Netflix_data.dropna()
director_name = input("Enter the director's name:- ")
director = Netflix_data_new[Netflix_data_new.Director.str.contains(director_name)]
director
# Out:
# Enter the director's name:- Keanu Reeves
#      Show_Id Category           Title      Director  \
# 3895   s3896    Movie  Man of Tai Chi  Keanu Reeves
#
#                                                    Cast  \
# 3895  Keanu Reeves, Tiger Chen, Karen Mok, Simon Yam...
#
#                               Country   Release_Date Rating Duration  \
# 3895  United States, China, Hong Kong  July 26, 2018      R  105 min
#
#                             Type  \
# 3895  Action & Adventure, Dramas
#
#                                             Description    Year
# 3895  In this kung fu tale set in Beijing, a young m...  2018.0

# %%
#7
Netflix_data_new = Netflix_data.dropna()
Cast_name = input('Enter Cast name:- ')
Netflix_data_new[Netflix_data_new['Cast'].str.contains(Cast_name)]
# Out:
# Enter Cast name:- Keanu Reeves
#      Show_Id Category                   Title  \
# 3424   s3425    Movie             Knock Knock
# 3895   s3896    Movie          Man of Tai Chi
# 5710   s5710    Movie  Something's Gotta Give
# 5752   s5752    Movie                  SPF-18
# 6108   s6108    Movie           The Bad Batch
# 6544   s6543    Movie          The Lake House
# 6650   s6649    Movie              The Matrix
# 6651   s6650    Movie     The Matrix Reloaded
# 6652   s6651    Movie  The Matrix Revolutions
# 7119   s7118    Movie             To the Bone
#
#                              Director  \
# 3424                         Eli Roth
# 3895                     Keanu Reeves
# 5710                     Nancy Meyers
# 5752                      Alex Israel
# 6108                Ana Lily Amirpour
# 6544                Alejandro Agresti
# 6650  Lilly Wachowski, Lana Wachowski
# 6651  Lilly Wachowski, Lana Wachowski
# 6652  Lilly Wachowski, Lana Wachowski
# ...

# %%
Netflix_data.Rating.value_counts()
# Out:
# TV-MA       2863
# TV-14       1931
# TV-PG        806
# R            665
# PG-13        386
# TV-Y         280
# TV-Y7        271
# PG           247
# TV-G         194
# NR            84
# G             39
# TV-Y7-FV       6
# UR             5
# NC-17          3
# Name: Rating, dtype: int64

# %%
plt.figure(figsize=(12,12))
plt.bar(Netflix_data.Rating.value_counts().keys(), Netflix_data.Rating.value_counts().values, color = ['C0','C1','C2','C3','C4','C5','C6','C7'])
# Out:
# <BarContainer object of 14 artists>

# %%
Netflix_data.groupby('Category').count()
# Out:
#           Show_Id  Title  Director  Cast  Country  Release_Date  Rating  \
# Category
# Movie        5377   5377      5214  4951     5147          5377    5372
# TV Show      2410   2410       185  2118     2133          2400    2408
#
#           Duration  Type  Description  Year
# Category
# Movie         5377  5377         5377  5377
# TV Show       2410  2410         2410  2400

# %%
plt.figure(figsize=(12,12))
sns.heatmap(Netflix_data.groupby('Category').count())
# Out:
# <AxesSubplot:ylabel='Category'>

# %%
plt.figure(figsize=(12,12))
movie_per_year = Netflix_data[(Netflix_data.Category == 'Movie')]
show_per_year = Netflix_data[(Netflix_data.Category == 'TV Show')]
plt.plot(show_per_year.Year.value_counts().sort_index().keys(), show_per_year.Year.value_counts().sort_index().values)
plt.plot(movie_per_year.Year.value_counts().sort_index().keys(), movie_per_year.Year.value_counts().sort_index().values)

# %%
country = input('Enter the country:- ')
category = input('Enter the Category:- ')
Netflix_data[(Netflix_data['Category'] == category) & (Netflix_data['Country'] == country)]
# Out:
# Enter the country:- France
# Enter the Category:- Movie
#      Show_Id Category                               Title  \
# 49       s50    Movie                      10 jours en or
# 77       s78    Movie                    2 Alone in Paris
# 203     s204    Movie                       A Mighty Team
# 309     s310    Movie                    Addicted to Life
# 489     s490    Movie                        An Easy Girl
# ...      ...      ...                                 ...
# 7446   s7445    Movie  Voulez-vous rire avec moi ce soir?
# 7474   s7473    Movie                     Wandering Stars
# 7500   s7499    Movie                          We Are One
# 7519   s7518    Movie                   Wedding Unplanned
# 7538   s7537    Movie                          West Coast
#
#                        Director  \
# 49            Nicolas Brossette
# 77      Ramzy Bedia, Éric Judor
# 203             Thomas Sorriaux
# 309              Thierry Donard
# 489           Rebecca Zlotowski
# ...

# %%
Netflix_data[(Netflix_data['Category'] == category) & (Netflix_data['Country'].str.contains(country))]
# Out:
#      Show_Id Category                                              Title  \
# 49       s50    Movie                                     10 jours en or
# 77       s78    Movie                                   2 Alone in Paris
# 96       s97    Movie                                     3 Days to Kill
# 105     s106    Movie                                300 Miles to Heaven
# 162     s163    Movie  A Christmas Special: Miraculous: Tales of Lady...
# ...      ...      ...                                                ...
# 7621   s7620    Movie                                         Wild Child
# 7635   s7634    Movie                                             Winnie
# 7706   s7705    Movie                                         Yellowbird
# 7744   s7743    Movie                                           Your Son
# 7749   s7748    Movie                                             اشتباك
#
#                      Director  \
# 49          Nicolas Brossette
# ...

# %%
Type = input('Enter the Type of show:- ')
category = input('Enter the Category:- ')
Netflix_data[(Netflix_data['Category'] == category) & (Netflix_data['Type'].str.contains(Type))]
# Out:
# Enter the Type of show:- Horror
# Enter the Category:- TV Show
#      Show_Id Category                        Title Director  \
# 188     s189  TV Show            A House of Blocks      NaN
# 468     s469  TV Show        American Horror Story      NaN
# 533     s534  TV Show          Anjaan: Rural Myths      NaN
# 534     s535  TV Show  Anjaan: Special Crimes Unit      NaN
# 575     s576  TV Show                         Ares      NaN
# ...      ...      ...                          ...      ...
# 7291   s7290  TV Show  Two Sentence Horror Stories      NaN
# 7294   s7293  TV Show                   Typewriter      NaN
# 7382   s7381  TV Show                       V Wars      NaN
# 7390   s7389  TV Show                     Vampires      NaN
# 7757   s7756  TV Show                     Z Nation      NaN
#
#                                                    Cast        Country  \
# 188   Eli Shi, Phoebe Lin, Chen Wan-ting, Fan Chen-f...         Taiwan
# ...

# %%
colors = sns.color_palette('pastel')[0:5]

plt.figure(figsize=(12,12))
plt.pie(Netflix_data.Rating.value_counts().values,labels = Netflix_data.Rating.value_counts().keys(), colors = colors, autopct='%.0f%%')
plt.show()

# %%
Netflix_data.Country.value_counts()
# Out:
# United States                                     2555
# India                                              923
# United Kingdom                                     397
# Japan                                              226
# South Korea                                        183
#                                                   ...
# United Kingdom, Germany, France, United States       1
# Germany, United States, France                       1
# South Korea, China, United States                    1
# Argentina, United States, Mexico                     1
# Hong Kong, Iceland, United States                    1
# Name: Country, Length: 681, dtype: int64
